# %%
import numpy as np
import pandas as pd
import os
print(os.listdir("C:\\Users\\Administrator\\JupyterNotebook"))
# Out:
# ['.condarc', '.git', '.git-for-windows-updater', '.ipynb_checkpoints', '.packettracer', 'calulate.ipynb', 'def.ipynb', 'dropna + drop_duplicates.ipynb', 'if_else_while.ipynb', 'join_group by.ipynb', 'Ndarray.ipynb', 'onlineretail.csv', 'Pandas_series_Dataframe.ipynb', 'SELECT_WHERE.ipynb', 'str_list.ipynb', 'Superstore.csv', 'Titanic Dataset.csv', 'Untitled.ipynb']

# %%
import numpy as np
import pandas as pd
import os
print(os.getcwd())
df=pd.read_csv('Superstore.csv', encoding='utf-8', encoding_errors='ignore')
print(df)

print(df.head())

# 查看后5行
print(df.tail())

# 查看数据形状（行数, 列数）
print(df.shape)

# 查看列名和数据类型
print(df.info())

# 查看数值列的统计摘要
print(df.describe())
# Out:
# C:\Users\Administrator\JupyterNotebook
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   2013/11/9  2013/11/12    Second Class
# 1          2  CA-2013-152156   2013/11/9  2013/11/12    Second Class
# 2          3  CA-2013-138688   2013/6/13   2013/6/17    Second Class
# 3          4  US-2012-108966  2012/10/11  2012/10/18  Standard Class
# 4          5  US-2012-108966  2012/10/11  2012/10/18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422   2011/1/22   2011/1/24    Second Class
# 9990    9991  CA-2014-121258   2014/2/27    2014/3/4  Standard Class
# 9991    9992  CA-2014-121258   2014/2/27    2014/3/4  Standard Class
# 9992    9993  CA-2014-121258   2014/2/27    2014/3/4  Standard Class
# 9993    9994  CA-2014-119914    2014/5/5   2014/5/10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...
